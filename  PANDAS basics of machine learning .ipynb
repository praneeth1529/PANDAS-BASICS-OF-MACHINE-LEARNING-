# %% [markdown]
# Importing Pandas and as well as required Files from the Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# Reading CSV file for the Pandas Commands

# %%
ds =pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %% [markdown]
# Displaying the CSV File

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(70):
 age.append(random.randint(0,70))
 weight.append(random.randint(0,70))
 height.append(random.randint(0,70))
 speed.append(random.randint(0,70))
idata = {'Age':age,'height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [28,
#   32,
#   58,
#   65,
#   34,
#   12,
#   36,
#   7,
#   7,
#   53,
#   31,
#   1,
#   45,
#   49,
#   40,
#   37,
#   47,
#   1,
#   59,
#   25,
#   32,
#   57,
#   52,
#   4,
#   51,
#   62,
#   21,
#   1,
#   8,
#   18,
#   32,
#   1,
#   44,
#   50,
#   28,
#   9,
#   45,
#   36,
#   23,
#   22,
#   55,
#   48,
#   59,
#   60,
#   62,
#   57,
#   61,
#   63,
#   15,
#   42,
#   16,
#   48,
#   50,
#   18,
#   48,
#   13,
#   25,
#   15,
#   2,
#   10,
#   30,
#   19,
#   9,
#   11,
#   13,
#   66,
#   38,
#   8,
#   8,
#   25],
#  'height': [43,
#   1,
#   34,
#   61,
#   68,
#   27,
#   19,
#   15,
#   43,
#   5,
#   4,
#   19,
#   50,
#   22,
#   16,
#   54,
#   27,
#   67,
#   63,
#   19,
#   24,
#   5,
#   57,
#   7,
#   25,
#   63,
#   4,
#   23,
#   1,
#   61,
#   2,
#   58,
#   43,
#   55,
#   32,
#   24,
#   66,
#   50,
#   9,
#   55,
#   3,
#   21,
#   64,
#   30,
#   65,
#   7,
#   43,
#   7,
#   16,
#   18,
#   10,
#   41,
#   17,
#   6,
#   18,
#   68,
# ...

# %% [markdown]
# Converting Dictionary into DataFrames

# %%
df=pd.DataFrame(idata)

# %%
df
# Out:
#     Age  height  Weight  Speed
# 0    28      43      29     60
# 1    32       1      22     30
# 2    58      34       3     62
# 3    65      61      23     17
# 4    34      68      27     33
# ..  ...     ...     ...    ...
# 65   66      38      16     17
# 66   38      60      68     67
# 67    8      66      53     22
# 68    8      29      56     63
# 69   25      32      38     56
#
# [70 rows x 4 columns]

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %% [markdown]
# Tail()-read and display values from the end

# %%
df.tail(10)
# Out:
#     Age  height  Weight  Speed
# 60   30      46      70     17
# 61   19       3      39     68
# 62    9      46      37     32
# 63   11      16       3      4
# 64   13      65       7     56
# 65   66      38      16     17
# 66   38      60      68     67
# 67    8      66      53     22
# 68    8      29      56     63
# 69   25      32      38     56

# %% [markdown]
# Head() - read and display values from the beginning

# %%
df.head(10)
# Out:
#    Age  height  Weight  Speed
# 0   28      43      29     60
# 1   32       1      22     30
# 2   58      34       3     62
# 3   65      61      23     17
# 4   34      68      27     33
# 5   12      27       1     24
# 6   36      19      44     32
# 7    7      15       6      9
# 8    7      43      62      8
# 9   53       5      65     45

# %%
df.describe()
# Out:
#              Age     Weight      Speed
# count  70.000000  70.000000  70.000000
# mean   32.242857  32.400000  35.028571
# std    20.110878  21.317748  20.445028
# min     1.000000   0.000000   2.000000
# 25%    13.500000  15.250000  17.500000
# 50%    32.000000  30.500000  33.000000
# 75%    49.750000  50.750000  52.750000
# max    66.000000  70.000000  69.000000

# %%
df[["Age","Weight"]]
# Out:
#         Age  Weight
# height
# 43       28      29
# 1        32      22
# 34       58       3
# 61       65      23
# 68       34      27
# ...     ...     ...
# 38       66      16
# 60       38      68
# 66        8      53
# 29        8      56
# 32       25      38
#
# [70 rows x 2 columns]

# %%
df.loc[[1,3],["Age","Weight"]]
# Out:
#         Age  Weight
# height
# 1        32      22
# 1         8       0
# 3        55      16
# 3        19      39

# %%
df1 = df[["Age","Weight"]]

# %%
df1
# Out:
#         Age  Weight
# height
# 43       28      29
# 1        32      22
# 34       58       3
# 61       65      23
# 68       34      27
# ...     ...     ...
# 38       66      16
# 60       38      68
# 66        8      53
# 29        8      56
# 32       25      38
#
# [70 rows x 2 columns]

# %%
df1.describe()
# Out:
#              Age     Weight
# count  70.000000  70.000000
# mean   32.242857  32.400000
# std    20.110878  21.317748
# min     1.000000   0.000000
# 25%    13.500000  15.250000
# 50%    32.000000  30.500000
# 75%    49.750000  50.750000
# max    66.000000  70.000000

# %%
df1.sort_index(ascending = True)
# Out:
#         Age  Weight
# height
# 1        32      22
# 1         8       0
# 2        32      60
# 3        19      39
# 3        55      16
# ...     ...     ...
# 66       45      18
# 67        1      21
# 68       25      55
# 68       13       6
# 68       34      27
#
# [70 rows x 2 columns]

# %%
df1[0::2].describe()
# Out:
#              Age     Weight
# count  35.000000  35.000000
# mean   34.628571  34.885714
# std    17.764945  22.315612
# min     2.000000   0.000000
# 25%    22.000000  14.000000
# 50%    34.000000  37.000000
# 75%    49.000000  54.500000
# max    62.000000  70.000000

# %%
# Filter
filter1 = df1['Weight'] > 50

# %%
df1[filter1]
# Out:
#         Age  Weight
# height
# 43        7      62
# 5        53      65
# 50       45      65
# 16       40      53
# 25       51      55
# 2        32      60
# 58        1      68
# 55       50      68
# 65       62      61
# 10       16      51
# 17       50      51
# 6        18      54
# 68       25      55
# 8         2      54
# 46       30      70
# 60       38      68
# 66        8      53
# 29        8      56

# %%
df1.loc[filter1]
# Out:
#         Age  Weight
# height
# 43        7      62
# 5        53      65
# 50       45      65
# 16       40      53
# 25       51      55
# 2        32      60
# 58        1      68
# 55       50      68
# 65       62      61
# 10       16      51
# 17       50      51
# 6        18      54
# 68       25      55
# 8         2      54
# 46       30      70
# 60       38      68
# 66        8      53
# 29        8      56

# %%
filter2 = df1['Age'] > 50

# %%
df1[filter1 | filter2]
# Out:
#         Age  Weight
# height
# 34       58       3
# 61       65      23
# 43        7      62
# 5        53      65
# 50       45      65
# 16       40      53
# 63       59      44
# 5        57      49
# 57       52      44
# 25       51      55
# 63       62       4
# 2        32      60
# 58        1      68
# 55       50      68
# 3        55      16
# 64       59      11
# 30       60      39
# 65       62      61
# 7        57       2
# 43       61      12
# 7        63      48
# 10       16      51
# 17       50      51
# 6        18      54
# 68       25      55
# 8         2      54
# 46       30      70
# 38       66      16
# 60       38      68
# 66        8      53
# 29        8      56

# %%
df1.loc[filter1 & filter2]
# Out:
#         Age  Weight
# height
# 5        53      65
# 25       51      55
# 65       62      61

# %% [markdown]
# iloc is used to read and display specific rows

# %% [markdown]
# To print out the number of rows we want with integer as the row identifier

# %%
df.iloc[0]
# Out:
# Age       28
# height    43
# Weight    29
# Speed     60
# Name: 0, dtype: int64

# %% [markdown]
# We can also make a new DataFrame with iloc[ [ ] ]

# %%
df.iloc[[0,1,2]]#Prints 3 rows with index -0,1,2
# Out:
#    Age  height  Weight  Speed
# 0   28      43      29     60
# 1   32       1      22     30
# 2   58      34       3     62

# %% [markdown]
# iloc[[r1,r2,....,rn],[c1,c2,...cn]] - to read the specific column value to the corresponding row value. We must only use integers for all the specifying values in the "[ ]"

# %%
df.iloc[[1,3,4],[2,3,1]]
# Out:
#    Weight  Speed  height
# 1      22     30       1
# 3      23     17      61
# 4      27     33      68

# %%
df.iloc[[1],[1,2,3]]
# Out:
#    height  Weight  Speed
# 1       1      22     30

# %% [markdown]
# Using loc[ ] we can read and print the values using the column labels.
#
# Syntax - ds.loc[[r1,r2,....rn],[c_name1,c_name2,....c_name_n]]

# %%
df.loc[[0,2],['Age','Weight']]
# Out:
#    Age  Weight
# 0   28      29
# 2   58       3

# %% [markdown]
# Individual Value for a specific plot

# %%
df.loc[1,"Weight"]
# Out:
# height
# 1    22
# 1     0
# Name: Weight, dtype: int64

# %%
df.loc[[1,2,3],"Age"]
# Out:
# 1    32
# 2    58
# 3    65
# Name: Age, dtype: int64

# %%
#slicing using the loc
df.loc[1:3,"Age":"Speed"]
# Out:
#    Age  height  Weight  Speed
# 1   32       1      22     30
# 2   58      34       3     62
# 3   65      61      23     17

# %%
df.loc[1:3:2,"Age":"Weight":2]
# Out:
#    Age  Weight
# 1   32      22
# 3   65      23

# %%
df.loc[1:4]
# Out:
#    Age  height  Weight  Speed
# 1   32       1      22     30
# 2   58      34       3     62
# 3   65      61      23     17
# 4   34      68      27     33

# %%
#slicing the rows
ds.loc[1:3]
# Out:
#    CustomerID  A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 1    15739548   0  22.67   7.00   2   8   4  0.165   0   0    0    0    2
# 2    15662854   0  29.58   1.75   1   4   4  1.250   0   0    0    1    2
# 3    15687688   0  21.67  11.50   1   5   3  0.000   1   1   11    1    2
#
#    A13  A14  Class
# 1  160    1      0
# 2  280    1      0
# 3    0    1      1

# %%
df.loc[1:5:2]
# Out:
#    Age  height  Weight  Speed
# 1   32       1      22     30
# 3   65      61      23     17
# 5   12      27       1     24

# %%
#slicing the columns
df.loc[0:1]
# Out:
#    Age  height  Weight  Speed
# 0   28      43      29     60
# 1   32       1      22     30

# %%
df.loc[0:1,"height":"Speed":2]
# Out:
#    height  Speed
# 0      43     60
# 1       1     30

# %% [markdown]
# Set an index using : ds.set_index('column_name',inplace=True)
# #Inplace=true}makes the dataset permanent

# %%
df.set_index("height",inplace=True)

# %% [markdown]
# Here height is the index for this present Dataset

# %%
df
# Out:
#         Age  Weight  Speed
# height
# 43       28      29     60
# 1        32      22     30
# 34       58       3     62
# 61       65      23     17
# 68       34      27     33
# ...     ...     ...    ...
# 38       66      16     17
# 60       38      68     67
# 66        8      53     22
# 29        8      56     63
# 32       25      38     56
#
# [70 rows x 3 columns]

# %% [markdown]
# Reset index using : reset_index(inplace=True)

# %%
df.reset_index(inplace=True)

# %% [markdown]
# Now the "height" label is not index anymore

# %%
df
# Out:
#     height  Age  Weight  Speed
# 0       43   28      29     60
# 1        1   32      22     30
# 2       34   58       3     62
# 3       61   65      23     17
# 4       68   34      27     33
# ..     ...  ...     ...    ...
# 65      38   66      16     17
# 66      60   38      68     67
# 67      66    8      53     22
# 68      29    8      56     63
# 69      32   25      38     56
#
# [70 rows x 4 columns]

# %% [markdown]
# Queries Usage after "set_index".
# Setting close as index

# %%
df.set_index("height",inplace=True)

# %%
df
# Out:
#         Age  Weight  Speed
# height
# 43       28      29     60
# 1        32      22     30
# 34       58       3     62
# 61       65      23     17
# 68       34      27     33
# ...     ...     ...    ...
# 38       66      16     17
# 60       38      68     67
# 66        8      53     22
# 29        8      56     63
# 32       25      38     56
#
# [70 rows x 3 columns]

# %% [markdown]
# read row with index of close at "66"

# %%
df.loc[66]
# Out:
#         Age  Weight  Speed
# height
# 66       45      18     33
# 66        8      53     22
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Speed'].plot(kind='hist', bins=20, title='Speed')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='Age', y='Weight', s=32, alpha=.8)
# ...

# %% [markdown]
# Sort using Filter
#
# Sorting the dataset using >>> :::sort_index(ascending=True/False,inplace=True)Sort using Filter

# %%
df
# Out:
#         Age  Weight  Speed
# height
# 43       28      29     60
# 1        32      22     30
# 34       58       3     62
# 61       65      23     17
# 68       34      27     33
# ...     ...     ...    ...
# 38       66      16     17
# 60       38      68     67
# 66        8      53     22
# 29        8      56     63
# 32       25      38     56
#
# [70 rows x 3 columns]

# %% [markdown]
# deafult sort for ascending value is True

# %%
df.sort_index()
# Out:
#         Age  Weight  Speed
# height
# 1        32      22     30
# 1         8       0     36
# 2        32      60     24
# 3        19      39     68
# 3        55      16     34
# ...     ...     ...    ...
# 66       45      18     33
# 67        1      21     52
# 68       25      55     64
# 68       13       6     32
# 68       34      27     33
#
# [70 rows x 3 columns]

# %% [markdown]
# Reverse the sort

# %%
df.sort_index(ascending=False)
# Out:
#         Age  Weight  Speed
# height
# 68       25      55     64
# 68       13       6     32
# 68       34      27     33
# 67        1      21     52
# 66       45      18     33
# ...     ...     ...    ...
# 3        55      16     34
# 3        19      39     68
# 2        32      60     24
# 1        32      22     30
# 1         8       0     36
#
# [70 rows x 3 columns]
